# %% [markdown]
# # 1 Data Cleaning no impute (incomplete)

# %% [markdown]
# # 0) Import Modules

# %%
import os
from zipfile import ZipFile

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %% [markdown]
# # 1) Load Data

# %%
os.chdir("/Users/anhthyngo/ds-ga1001-master/")

# %%
cwd = os.getcwd()
datadir = '/'.join(cwd.split('/')) + '/data/'
listings = datadir + 'listings.csv.zip'
print(listings)
# Out:
# /Users/anhthyngo/ds-ga1001-master/data/listings.csv.zip

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
zf = ZipFile(listings) 
data = pd.read_csv(zf.open("listings.csv"), parse_dates=['host_since', 'first_review', 'last_review'], low_memory=False)
data.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3647  https://www.airbnb.com/rooms/3647  20190912153101   2019-09-13
# 1  3831  https://www.airbnb.com/rooms/3831  20190912153101   2019-09-13
# 2  5022  https://www.airbnb.com/rooms/5022  20190912153101   2019-09-13
#
#                                                name  \
# 0               THE VILLAGE OF HARLEM....NEW YORK !
# 1                   Cozy Entire Floor of Brownstone
# 2  Entire Apt: Spacious Studio/Loft by central park
#
#                                              summary  \
# 0                                                NaN
# 1  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 2                                                NaN
#
#                                                space  \
# 0  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 1  Greetings!      We own a double-duplex brownst...
# 2  Loft apartment with high ceiling and wood floo...
#
#                                          description experiences_offered  \
# 0  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
# 1  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 2  Loft apartment with high ceiling and wood floo...                none
#
#                                neighborhood_overview notes  \
# 0                                                NaN   NaN
# 1  Just the right mix of urban center and local n...   NaN
# 2                                                NaN   NaN
#
#                                              transit  \
# 0                                                NaN
# 1  B52 bus for a 10-minute ride to downtown Brook...
# 2                                                NaN
#
#                                               access  \
# 0                                                NaN
# 1  You will have exclusive use of and access to: ...
# 2                                                NaN
#
#                                          interaction  \
# 0                                                NaN
# 1  We'll be around, but since you have the top fl...
# 2                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  Upon arrival please have a legibile copy of yo...            NaN
# 1  Smoking - outside please; pets allowed but ple...            NaN
# 2  Please be considerate when staying in the apar...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/838341/9b3...
# 1         NaN  https://a0.muscache.com/im/pictures/e49999c2-9...
# 2         NaN  https://a0.muscache.com/im/pictures/feb453bd-f...
#
#    xl_picture_url  host_id                                host_url  \
# 0             NaN     4632  https://www.airbnb.com/users/show/4632
# 1             NaN     4869  https://www.airbnb.com/users/show/4869
# 2             NaN     7192  https://www.airbnb.com/users/show/7192
#
#      host_name host_since                      host_location  \
# 0    Elisabeth 2008-11-25  New York, New York, United States
# 1  LisaRoxanne 2008-12-07  New York, New York, United States
# 2        Laura 2009-01-29      Miami, Florida, United States
#
#                                           host_about  host_response_time  \
# 0  Make Up Artist National/ (Website hidden by Ai...  a few days or more
# 1     Laid-back bi-coastal actor/professor/attorney.      within an hour
# 2  I have been a NYer for almost 10 years. I came...                 NaN
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 0%                   NaN                 f
# 1                92%                   NaN                 f
# 2                NaN                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/4632/profile_...
# 1  https://a0.muscache.com/im/users/4869/profile_...
# 2  https://a0.muscache.com/im/users/7192/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/4632/profile_...             Harlem
# 1  https://a0.muscache.com/im/users/4869/profile_...       Clinton Hill
# 2  https://a0.muscache.com/im/users/7192/profile_...        East Harlem
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 1               ['email', 'phone', 'reviews', 'kba']                    t
# 2   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
#
#   host_identity_verified                       street neighbourhood  \
# 0                      t  New York, NY, United States        Harlem
# 1                      t  Brooklyn, NY, United States      Brooklyn
# 2                      t  New York, NY, United States   East Harlem
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city state zipcode  \
# 0                 Harlem                    Manhattan  New York    NY   10027
# 1           Clinton Hill                     Brooklyn  Brooklyn    NY   11238
# 2            East Harlem                    Manhattan  New York    NY   10029
#
#      market smart_location country_code        country  latitude  longitude  \
# 0  New York   New York, NY           US  United States  40.80902  -73.94190
# 1  New York   Brooklyn, NY           US  United States  40.68514  -73.95976
# 2  New York   New York, NY           US  United States  40.79851  -73.94399
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t     Apartment     Private room             2        1.0
# 1                 t   Guest suite  Entire home/apt             3        1.0
# 2                 t     Apartment  Entire home/apt             1        1.0
#
#    bedrooms  beds       bed_type  \
# 0       1.0   1.0  Pull-out Sofa
# 1       1.0   4.0       Real Bed
# 2       NaN   1.0       Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {"Cable TV",Internet,Wifi,"Air conditioning",K...          NaN  $150.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        500.0   $89.00
# 2  {Internet,Wifi,"Air conditioning",Kitchen,Elev...          NaN   $80.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $200.00       $75.00                2
# 1      $575.00     $2,100.00          $500.00          NaN                1
# 2      $600.00     $1,600.00          $100.00       $80.00                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $20.00               3               7                       3
# 1        $0.00               1             730                       1
# 2       $20.00              10             120                      10
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                       7                       7
# 1                       1                     730                     730
# 2                      10                     120                     120
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                     7.0    37 months ago
# 1                     1.0                   730.0       3 days ago
# 2                    10.0                   120.0     6 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               30               60               90
# 1                t                1                3                8
# 2                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               365            2019-09-13                  0
# 1               192            2019-09-13                279
# 2                 0            2019-09-13                  9
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0          NaT         NaT                   NaN
# 1                     67   2014-09-30  2019-08-29                  90.0
# 2                      2   2012-03-20  2018-11-19                  93.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     NaN                        NaN                    NaN
# 1                     9.0                        9.0                   10.0
# 2                    10.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          9.0                    10.0                  9.0
# 2                         10.0                     9.0                 10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 1                             f                                f
# 2                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               4.62
# 2                                            0               0.10

# %% [markdown]
# # 2) Cleaning Data

# %% [markdown]
# ### 2.1 Drop irrelevant columns

# %%
data = data.drop(["id","market","is_location_exact","listing_url","scrape_id","last_scraped","name","summary","space","description",\
                  "experiences_offered","neighborhood_overview","notes","transit","access","interaction", \
                 "house_rules","thumbnail_url","medium_url","picture_url","xl_picture_url","host_id","host_url",\
                  "host_name","host_about","host_thumbnail_url","host_picture_url","calendar_last_scraped"\
                  ,"country","country_code","state","host_since","first_review","last_review","host_location",\
                  "host_response_time","host_neighbourhood","street" ,"neighbourhood"],axis = 1)
data.head(2)
# Out:
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 0%                   NaN                 f
# 1                92%                   NaN                 f
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 1               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0                      t                 Harlem                    Manhattan
# 1                      t           Clinton Hill                     Brooklyn
#
#        city zipcode smart_location  latitude  longitude property_type  \
# 0  New York   10027   New York, NY  40.80902  -73.94190     Apartment
# 1  Brooklyn   11238   Brooklyn, NY  40.68514  -73.95976   Guest suite
#
#          room_type  accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0     Private room             2        1.0       1.0   1.0  Pull-out Sofa
# 1  Entire home/apt             3        1.0       1.0   4.0       Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {"Cable TV",Internet,Wifi,"Air conditioning",K...          NaN  $150.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        500.0   $89.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $200.00       $75.00                2
# 1      $575.00     $2,100.00          $500.00          NaN                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $20.00               3               7                       3
# 1        $0.00               1             730                       1
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                       7                       7
# 1                       1                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                     7.0    37 months ago
# 1                     1.0                   730.0       3 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               30               60               90
# 1                t                1                3                8
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0               365                  0                      0
# 1               192                279                     67
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                   NaN                     NaN                        NaN
# 1                  90.0                     9.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                    NaN                          NaN                     NaN
# 1                   10.0                          9.0                    10.0
#
#    review_scores_value requires_license license jurisdiction_names  \
# 0                  NaN                f     NaN                NaN
# 1                  9.0                f     NaN                NaN
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                f                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 1                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               4.62

# %%
print("There are",data.shape[0],"rows and", data.shape[1],"columns.")
# Out:
# There are 48377 rows and 67 columns.

# %% [markdown]
# ### 2.2 Handle Missing Values
# We will check dataset for missing values. If a column has more than 50% of values missing, we will drop the column.

# %%
for col in list(data.columns):
    count_miss_ratio = pd.isnull(data[col]).sum()/len(data)*100
    if count_miss_ratio > 50:
        print("%0.2f %% observations missing for %s." % (float(count_miss_ratio),col))
        data = data.drop([col], axis=1)
# Out:
# 100.00 % observations missing for host_acceptance_rate.
# 99.22 % observations missing for square_feet.
# 88.11 % observations missing for weekly_price.
# 89.66 % observations missing for monthly_price.
# 99.96 % observations missing for license.
# 99.98 % observations missing for jurisdiction_names.

# %%
print("There are",data.shape[0],"rows and", data.shape[1],"columns.")
# Out:
# There are 48377 rows and 61 columns.

# %% [markdown]
# If there are only a few missing observations for a specific feature, we will just ignore the missing entry data.

# %%
for col in list(data.columns):
    count_miss_ratio = pd.isnull(data[col]).sum()/len(data)*100
    #if count_miss_ratio != 0 and count_miss_ratio < 1:
    if count_miss_ratio > 0:
        print("%0.2f %% observations missing for %s." % (float(count_miss_ratio),col))
# Out:
# 33.93 % observations missing for host_response_rate.
# 0.04 % observations missing for host_is_superhost.
# 0.04 % observations missing for host_listings_count.
# 0.04 % observations missing for host_total_listings_count.
# 0.04 % observations missing for host_has_profile_pic.
# 0.04 % observations missing for host_identity_verified.
# 0.14 % observations missing for city.
# 0.97 % observations missing for zipcode.
# 0.10 % observations missing for bathrooms.
# 0.08 % observations missing for bedrooms.
# 0.07 % observations missing for beds.
# 34.98 % observations missing for security_deposit.
# 21.15 % observations missing for cleaning_fee.
# 21.83 % observations missing for review_scores_rating.
# 21.91 % observations missing for review_scores_accuracy.
# 21.88 % observations missing for review_scores_cleanliness.
# 21.94 % observations missing for review_scores_checkin.
# 21.90 % observations missing for review_scores_communication.
# 21.95 % observations missing for review_scores_location.
# 21.95 % observations missing for review_scores_value.
# 19.95 % observations missing for reviews_per_month.

# %%
for col in list(data.columns):
    null_ratio = pd.isnull(data[col]).sum()/len(data)*100
    if null_ratio != 0 and null_ratio < 1:
    #if count_miss_ratio:
        print("%0.2f %% observations missing for %s." % (float(null_ratio),col))
        data = data[pd.notnull(data[col])]
# Out:
# 0.04 % observations missing for host_is_superhost.
# 0.14 % observations missing for city.
# 0.96 % observations missing for zipcode.
# 0.10 % observations missing for bathrooms.
# 0.08 % observations missing for bedrooms.
# 0.04 % observations missing for beds.

# %%
print("There are",data.shape[0],"rows and", data.shape[1],"columns.")
# Out:
# There are 47721 rows and 61 columns.

# %% [markdown]
# The rest of these features are numerical and we will impute them later.

# %%
for col in list(data.columns):
    null_ratio = pd.isnull(data[col]).sum()/len(data)*100
    if null_ratio != 0 and null_ratio > 1:
        print("%0.2f %% observations missing for %s." % (float(null_ratio),col))
# Out:
# 33.71 % observations missing for host_response_rate.
# 34.90 % observations missing for security_deposit.
# 21.08 % observations missing for cleaning_fee.
# 21.78 % observations missing for review_scores_rating.
# 21.86 % observations missing for review_scores_accuracy.
# 21.83 % observations missing for review_scores_cleanliness.
# 21.90 % observations missing for review_scores_checkin.
# 21.85 % observations missing for review_scores_communication.
# 21.90 % observations missing for review_scores_location.
# 21.90 % observations missing for review_scores_value.
# 19.91 % observations missing for reviews_per_month.

# %% [markdown]
# ### 2.3 Convert Numeric String features
# Currency features are currently strings, we will convert them to floats and we will impute them with the median for currency features with null values. We pick the median because `security_deposit` and `cleaning_fee` are extremely left-skewed and therefore median will be a better choice to deal with outliers.

# %%
money_attributes = ['extra_people', 'cleaning_fee', 'security_deposit', 'price']
money_floats = data[money_attributes].replace( '[\$,)]','', regex=True ).replace( '[(]','-',   regex=True ).astype(float)

money_floats.head()
# Out:
#    extra_people  cleaning_fee  security_deposit  price
# 0          20.0          75.0             200.0  150.0
# 1           0.0           NaN             500.0   89.0
# 3         100.0         125.0             300.0  200.0
# 5          12.0          15.0               NaN   79.0
# 6           0.0           NaN               NaN   79.0

# %%
sns.boxplot(x=money_floats['security_deposit'], color = 'lightblue')

# %%
sns.boxplot(x=money_floats['cleaning_fee'], color = 'pink')

# %%
#money_floats = money_floats.fillna(money_floats[['cleaning_fee', 'security_deposit']].mean())
data = data.drop(columns=['extra_people', 'cleaning_fee', 'security_deposit', 'price'])
data = pd.concat([data,money_floats],axis = 1)
#data.head()

# %%
data['zipcode'] = data['zipcode'].str.replace('NY ','').str[:5]
data = data[data['zipcode'] != ' ']
data['zipcode'] = data['zipcode'].astype(int)

# %% [markdown]
# ### 2.4 Convert Binary Columns
#
# Binary columns are labeled as either "True" or "False". Let's change them to the dummy values 1 and 0.

# %%
bool_attributes = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', \
                    'has_availability', 'requires_license', \
                   'instant_bookable', 'is_business_travel_ready', 'require_guest_profile_picture', \
                   'require_guest_phone_verification']
def bool_to_dummy(boo):
    boo = boo.replace('f', 0);
    boo = boo.replace('t', 1);
    return boo

data_bool_dummy = data[bool_attributes].apply(lambda col: bool_to_dummy(col))
data = data.drop(columns=['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', \
                    'has_availability', 'requires_license', \
                   'instant_bookable', 'is_business_travel_ready', 'require_guest_profile_picture', \
                   'require_guest_phone_verification'])
data = pd.concat([data,data_bool_dummy],axis = 1)

data.head(2)
# Out:
#   host_response_rate  host_listings_count  host_total_listings_count  \
# 0                 0%                  1.0                        1.0
# 1                92%                  1.0                        1.0
#
#                                   host_verifications neighbourhood_cleansed  \
# 0  ['email', 'phone', 'google', 'reviews', 'jumio...                 Harlem
# 1               ['email', 'phone', 'reviews', 'kba']           Clinton Hill
#
#   neighbourhood_group_cleansed      city  zipcode smart_location  latitude  \
# 0                    Manhattan  New York    10027   New York, NY  40.80902
# 1                     Brooklyn  Brooklyn    11238   Brooklyn, NY  40.68514
#
#    longitude property_type        room_type  accommodates  bathrooms  \
# 0  -73.94190     Apartment     Private room             2        1.0
# 1  -73.95976   Guest suite  Entire home/apt             3        1.0
#
#    bedrooms  beds       bed_type  \
# 0       1.0   1.0  Pull-out Sofa
# 1       1.0   4.0       Real Bed
#
#                                            amenities  guests_included  \
# 0  {"Cable TV",Internet,Wifi,"Air conditioning",K...                2
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...                1
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3               7                       3
# 1               1             730                       1
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                       7                       7
# 1                       1                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                     7.0    37 months ago
# 1                     1.0                   730.0       3 days ago
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               30               60               90               365
# 1                1                3                8               192
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                  0                      0                   NaN
# 1                279                     67                  90.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     NaN                        NaN                    NaN
# 1                     9.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          9.0                    10.0                  9.0
#
#            cancellation_policy  calculated_host_listings_count  \
# 0  strict_14_with_grace_period                               1
# 1                     moderate                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0                NaN
# 1                                            0               4.62
#
#    extra_people  cleaning_fee  security_deposit  price  host_is_superhost  \
# 0          20.0          75.0             200.0  150.0                  0
# 1           0.0           NaN             500.0   89.0                  0
#
#    host_has_profile_pic  host_identity_verified  has_availability  \
# 0                     1                       1                 1
# 1                     1                       1                 1
#
#    requires_license  instant_bookable  is_business_travel_ready  \
# 0                 0                 0                         0
# 1                 0                 0                         0
#
#    require_guest_profile_picture  require_guest_phone_verification
# 0                              1                                 1
# 1                              0                                 0

# %% [markdown]
# ### 2.5 Convert List Columns
# Some of the features are grouped into annoying lists.
# For example `host_verifications` is a column grouping all verified social media accounts / other information into an array. We will extract them out and create dummy variables for each.

# %%
array_attributes = ['host_verifications', 'amenities']

def get_arr(arr):
    arr = arr.str.replace('[', '');
    arr = arr.str.replace(']', '');
    arr = arr.str.replace('{', '');
    arr = arr.str.replace('}', '');
    arr = arr.str.replace("'", '');
    arr = arr.str.replace('"', '');
    return arr;

listings_arr_fixed = data[array_attributes].apply(lambda col: get_arr(col))

array_dummy_arrs = [];
for col in listings_arr_fixed.columns:
    dummy_arrs = listings_arr_fixed[col].str.get_dummies(sep=',');
    dummy_arrs = dummy_arrs.add_prefix(col + '_');
    array_dummy_arrs.append(dummy_arrs);

listings_arr_fixed = pd.concat(array_dummy_arrs, axis=1)
data = pd.concat([data,listings_arr_fixed],axis = 1)
data = data.drop(columns=['host_verifications', 'amenities'])
data.head(2)
# Out:
#   host_response_rate  host_listings_count  host_total_listings_count  \
# 0                 0%                  1.0                        1.0
# 1                92%                  1.0                        1.0
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city  zipcode  \
# 0                 Harlem                    Manhattan  New York    10027
# 1           Clinton Hill                     Brooklyn  Brooklyn    11238
#
#   smart_location  latitude  longitude property_type        room_type  \
# 0   New York, NY  40.80902  -73.94190     Apartment     Private room
# 1   Brooklyn, NY  40.68514  -73.95976   Guest suite  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  guests_included  \
# 0             2        1.0       1.0   1.0  Pull-out Sofa                2
# 1             3        1.0       1.0   4.0       Real Bed                1
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3               7                       3
# 1               1             730                       1
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                       7                       7
# 1                       1                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                     7.0    37 months ago
# 1                     1.0                   730.0       3 days ago
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               30               60               90               365
# 1                1                3                8               192
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                  0                      0                   NaN
# 1                279                     67                  90.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     NaN                        NaN                    NaN
# 1                     9.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          9.0                    10.0                  9.0
#
#            cancellation_policy  calculated_host_listings_count  \
# 0  strict_14_with_grace_period                               1
# 1                     moderate                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0                NaN
# 1                                            0               4.62
#
#    extra_people  cleaning_fee  security_deposit  price  host_is_superhost  \
# 0          20.0          75.0             200.0  150.0                  0
# 1           0.0           NaN             500.0   89.0                  0
#
#    host_has_profile_pic  host_identity_verified  has_availability  \
# 0                     1                       1                 1
# 1                     1                       1                 1
#
#    requires_license  instant_bookable  is_business_travel_ready  \
# 0                 0                 0                         0
# 1                 0                 0                         0
#
#    require_guest_profile_picture  require_guest_phone_verification  \
# 0                              1                                 1
# 1                              0                                 0
#
#    host_verifications_ facebook  host_verifications_ google  \
# 0                             0                           1
# 1                             0                           0
#
#    host_verifications_ government_id  host_verifications_ identity_manual  \
# 0                                  1                                    0
# 1                                  0                                    0
#
#    host_verifications_ jumio  host_verifications_ kba  \
# 0                          1                        0
# 1                          0                        1
#
#    host_verifications_ manual_offline  host_verifications_ manual_online  \
# 0                                   0                                  0
# 1                                   0                                  0
#
#    host_verifications_ offline_government_id  host_verifications_ phone  \
# 0                                          0                          1
# 1                                          0                          1
#
#    host_verifications_ reviews  host_verifications_ selfie  \
# 0                            1                           0
# 1                            1                           0
#
#    host_verifications_ sent_id  host_verifications_ sesame  \
# 0                            0                           0
# 1                            0                           0
#
#    host_verifications_ sesame_offline  host_verifications_ weibo  \
# 0                                   0                          0
# 1                                   0                          0
#
#    host_verifications_ work_email  host_verifications_ zhima_selfie  \
# 0                               0                                 0
# 1                               0                                 0
#
#    host_verifications_email  host_verifications_facebook  \
# 0                         1                            0
# 1                         1                            0
#
#    host_verifications_google  host_verifications_jumio  \
# 0                          0                         0
# 1                          0                         0
#
#    host_verifications_offline_government_id  host_verifications_phone  \
# 0                                         0                         0
# 1                                         0                         0
#
#    host_verifications_reviews  amenities_ toilet  amenities_24-hour check-in  \
# 0                           0                  0                           0
# 1                           0                  0                           1
#
#    amenities_Accessible-height bed  amenities_Accessible-height toilet  \
# 0                                0                                   0
# 1                                0                                   0
#
#    amenities_Air conditioning  amenities_Air purifier  amenities_BBQ grill  \
# 0                           1                       0                    0
# 1                           1                       0                    0
#
#    amenities_Baby bath  amenities_Baby monitor  \
# 0                    0                       0
# 1                    0                       0
#
#    amenities_Babysitter recommendations  amenities_Bathtub  \
# 0                                     0                  0
# 1                                     0                  1
#
#    amenities_Bathtub with bath chair  amenities_Beach essentials  \
# 0                                  0                           0
# 1                                  0                           0
#
#    amenities_Beachfront  amenities_Bed linens  amenities_Breakfast  \
# 0                     0                     0                    0
# 1                     0                     0                    0
#
#    amenities_Building staff  amenities_Buzzer/wireless intercom  \
# 0                         0                                   1
# 1                         0                                   0
#
#    amenities_Cable TV  amenities_Carbon monoxide detector  amenities_Cat(s)  \
# 0                   1                                   1                 0
# 1                   1                                   1                 0
#
#    amenities_Ceiling hoist  amenities_Changing table  \
# 0                        0                         0
# 1                        0                         0
#
#    amenities_Children’s books and toys  amenities_Children’s dinnerware  \
# 0                                    0                                0
# 1                                    1                                0
#
#    amenities_Cleaning before checkout  amenities_Coffee maker  \
# 0                                   0                       0
# 1                                   0                       1
#
#    amenities_Cooking basics  amenities_Crib  amenities_Disabled parking spot  \
# 0                         0               0                                0
# 1                         1               0                                0
#
#    amenities_Dishes and silverware  amenities_Dishwasher  amenities_Dog(s)  \
# 0                                0                     0                 0
# 1                                1                     0                 0
#
#    amenities_Doorman  amenities_Dryer  amenities_EV charger  \
# 0                  0                0                     0
# 1                  0                0                     0
#
#    amenities_Electric profiling bed  amenities_Elevator  amenities_Essentials  \
# 0                                 0                   0                     0
# 1                                 0                   0                     1
#
#    amenities_Ethernet connection  amenities_Extra pillows and blankets  \
# 0                              0                                     0
# 1                              0                                     0
#
#    amenities_Extra space around bed  amenities_Family/kid friendly  \
# 0                                 0                              0
# 1                                 0                              1
#
#    amenities_Fire extinguisher  amenities_Fireplace guards  \
# 0                            0                           0
# 1                            1                           0
#
#    amenities_Firm mattress  amenities_First aid kit  \
# 0                        0                        0
# 1                        0                        0
#
#    amenities_Fixed grab bars for shower  amenities_Fixed grab bars for toilet  \
# 0                                     0                                     0
# 1                                     0                                     0
#
#    amenities_Flat path to guest entrance  amenities_Free parking on premises  \
# 0                                      0                                   0
# 1                                      0                                   0
#
#    amenities_Free street parking  amenities_Full kitchen  \
# 0                              0                       0
# 1                              1                       0
#
#    amenities_Game console  amenities_Garden or backyard  \
# 0                       0                             0
# 1                       0                             0
#
#    amenities_Ground floor access  amenities_Gym  amenities_Hair dryer  \
# 0                              0              0                     0
# 1                              0              0                     1
#
#    amenities_Handheld shower head  amenities_Hangers  amenities_Heating  \
# 0                               0                  0                  1
# 1                               0                  1                  1
#
#    amenities_High chair  amenities_Host greets you  amenities_Hot tub  \
# 0                     0                          0                  0
# 1                     1                          0                  0
#
#    amenities_Hot water  amenities_Hot water kettle  \
# 0                    0                           0
# 1                    1                           0
#
#    amenities_Indoor fireplace  amenities_Internet  amenities_Iron  \
# 0                           0                   1               0
# 1                           0                   1               1
#
#    amenities_Keypad  amenities_Kitchen  amenities_Kitchenette  \
# 0                 0                  1                      0
# 1                 0                  1                      0
#
#    amenities_Lake access  amenities_Laptop friendly workspace  \
# 0                      0                                    0
# 1                      0                                    1
#
#    amenities_Lock on bedroom door  amenities_Lockbox  \
# 0                               0                  0
# 1                               1                  1
#
#    amenities_Long term stays allowed  amenities_Luggage dropoff allowed  \
# 0                                  0                                  0
# 1                                  1                                  1
#
#    amenities_Microwave  amenities_Mobile hoist  \
# 0                    0                       0
# 1                    1                       0
#
#    amenities_No stairs or steps to enter  amenities_Other  \
# 0                                      0                0
# 1                                      0                0
#
#    amenities_Other pet(s)  amenities_Outlet covers  amenities_Oven  \
# 0                       0                        0               0
# 1                       0                        0               1
#
#    amenities_Pack ’n Play/travel crib  amenities_Paid parking off premises  \
# 0                                   0                                    0
# 1                                   1                                    0
#
#    amenities_Paid parking on premises  amenities_Patio or balcony  \
# 0                                   0                           0
# 1                                   0                           0
#
#    amenities_Pets allowed  amenities_Pets live on this property  \
# 0                       0                                     0
# 1                       1                                     0
#
#    amenities_Pocket wifi  amenities_Pool  amenities_Pool with pool hoist  \
# 0                      0               0                               0
# 1                      0               0                               0
#
#    amenities_Private bathroom  amenities_Private entrance  \
# 0                           0                           0
# 1                           0                           0
#
#    amenities_Private living room  amenities_Refrigerator  \
# 0                              0                       0
# 1                              0                       1
#
#    amenities_Roll-in shower  amenities_Room-darkening shades  \
# 0                         0                                0
# 1                         0                                0
#
#    amenities_Safety card  amenities_Self check-in  amenities_Shampoo  \
# 0                      0                        0                  0
# 1                      0                        1                  1
#
#    amenities_Shower chair  amenities_Single level home  \
# 0                       0                            0
# 1                       0                            0
#
#    amenities_Ski-in/Ski-out  amenities_Smart lock  amenities_Smoke detector  \
# 0                         0                     0                         1
# 1                         0                     0                         1
#
#    amenities_Smoking allowed  amenities_Stair gates  amenities_Stove  \
# 0                          0                      0                0
# 1                          0                      1                1
#
#    amenities_Suitable for events  amenities_TV  amenities_Table corner guards  \
# 0                              0             0                              0
# 1                              0             1                              0
#
#    amenities_Washer  amenities_Washer / Dryer  amenities_Waterfront  \
# 0                 0                         0                     0
# 1                 0                         0                     0
#
#    amenities_Well-lit path to entrance  amenities_Wheelchair accessible  \
# 0                                    0                                0
# 1                                    0                                0
#
#    amenities_Wide clearance to shower  \
# 0                                   0
# 1                                   0
#
#    amenities_Wide doorway to guest bathroom  amenities_Wide entrance  \
# 0                                         0                        0
# 1                                         0                        0
#
#    amenities_Wide entrance for guests  amenities_Wide entryway  \
# 0                                   0                        0
# 1                                   0                        0
#
#    amenities_Wide hallways  amenities_Wifi  amenities_Window guards  \
# 0                        0               1                        0
# 1                        0               1                        0
#
#    amenities_translation missing: en.hosting_amenity_49  \
# 0                                                  1
# 1                                                  0
#
#    amenities_translation missing: en.hosting_amenity_50
# 0                                                  1
# 1                                                  0

# %% [markdown]
# ### 2.6 Dealing with Missing Values pt. 2
# OK let's impute those missing value columns now.

# %%
for col in list(data.columns):
    null_ratio = pd.isnull(data[col]).sum()/len(data)*100
    if null_ratio > 0:
        print("%0.2f %% observations missing for %s." % (float(null_ratio),col))
# Out:
# 33.72 % observations missing for host_response_rate.
# 21.78 % observations missing for review_scores_rating.
# 21.86 % observations missing for review_scores_accuracy.
# 21.83 % observations missing for review_scores_cleanliness.
# 21.90 % observations missing for review_scores_checkin.
# 21.85 % observations missing for review_scores_communication.
# 21.90 % observations missing for review_scores_location.
# 21.90 % observations missing for review_scores_value.
# 19.91 % observations missing for reviews_per_month.
# 21.08 % observations missing for cleaning_fee.
# 34.90 % observations missing for security_deposit.

# %%
data[['host_response_rate']] = data['host_response_rate'].apply(lambda col:float(str(col).strip('%'))/100)
data['host_response_rate'].head()

## impute with mean
#data['host_response_rate'] = data['host_response_rate'].fillna(np.mean(data['host_response_rate']))
# Out:
# 0    0.00
# 1    0.92
# 3    0.78
# 5    0.90
# 6     NaN
# Name: host_response_rate, dtype: float64

# %%
review_metrics = ['review_scores_rating','review_scores_accuracy','review_scores_cleanliness',\
                  'review_scores_checkin','review_scores_communication','review_scores_location'\
                  ,'review_scores_value','reviews_per_month']

## impute all review metrics with mean
#for col in review_metrics:
#    data[col] = data[col].fillna(np.mean(data[col]))

data.head()
# Out:
#    host_response_rate  host_listings_count  host_total_listings_count  \
# 0                0.00                  1.0                        1.0
# 1                0.92                  1.0                        1.0
# 3                0.78                  1.0                        1.0
# 5                0.90                  1.0                        1.0
# 6                 NaN                  1.0                        1.0
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city  zipcode  \
# 0                 Harlem                    Manhattan  New York    10027
# 1           Clinton Hill                     Brooklyn  Brooklyn    11238
# 3            Murray Hill                    Manhattan  New York    10016
# 5         Hell's Kitchen                    Manhattan  New York    10019
# 6        Upper West Side                    Manhattan  New York    10025
#
#   smart_location  latitude  longitude property_type        room_type  \
# 0   New York, NY  40.80902  -73.94190     Apartment     Private room
# 1   Brooklyn, NY  40.68514  -73.95976   Guest suite  Entire home/apt
# 3   New York, NY  40.74767  -73.97500     Apartment  Entire home/apt
# 5   New York, NY  40.76489  -73.98493     Apartment     Private room
# 6   New York, NY  40.80178  -73.96723     Apartment     Private room
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  guests_included  \
# 0             2        1.0       1.0   1.0  Pull-out Sofa                2
# 1             3        1.0       1.0   4.0       Real Bed                1
# 3             2        1.0       1.0   1.0       Real Bed                2
# 5             2        1.0       1.0   1.0       Real Bed                1
# 6             1        1.0       1.0   1.0       Real Bed                1
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3               7                       3
# 1               1             730                       1
# 3               3              21                       3
# 5               2              14                       1
# 6               2              14                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                       7                       7
# 1                       1                     730                     730
# 3                       3                      21                      21
# 5                       2                      14                      14
# 6                       2                      14                      14
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                     7.0    37 months ago
# 1                     1.0                   730.0       3 days ago
# 3                     3.0                    21.0            today
# 5                     1.8                    14.0       a week ago
# 6                     2.0                    14.0    26 months ago
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               30               60               90               365
# 1                1                3                8               192
# 3                3                3               13                13
# 5                1                5               10               246
# 6                0                0                0                 0
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                  0                      0                   NaN
# 1                279                     67                  90.0
# 3                 75                     10                  89.0
# 5                443                     49                  83.0
# 6                118                      0                  98.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     NaN                        NaN                    NaN
# 1                     9.0                        9.0                   10.0
# 3                    10.0                        9.0                   10.0
# 5                     8.0                        7.0                    9.0
# 6                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                  9.0
# 5                          9.0                    10.0                  8.0
# 6                         10.0                    10.0                 10.0
#
#            cancellation_policy  calculated_host_listings_count  \
# 0  strict_14_with_grace_period                               1
# 1                     moderate                               1
# 3                     moderate                               1
# 5  strict_14_with_grace_period                               1
# 6                     flexible                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 3                                            1
# 5                                            0
# 6                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
# 3                                             0
# 5                                             1
# 6                                             1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0                NaN
# 1                                            0               4.62
# 3                                            0               0.59
# 5                                            0               3.51
# 6                                            0               0.97
#
#    extra_people  cleaning_fee  security_deposit  price  host_is_superhost  \
# 0          20.0          75.0             200.0  150.0                  0
# 1           0.0           NaN             500.0   89.0                  0
# 3         100.0         125.0             300.0  200.0                  0
# 5          12.0          15.0               NaN   79.0                  0
# 6           0.0           NaN               NaN   79.0                  0
#
#    host_has_profile_pic  host_identity_verified  has_availability  \
# 0                     1                       1                 1
# 1                     1                       1                 1
# 3                     1                       0                 1
# 5                     1                       0                 1
# 6                     1                       1                 1
#
#    requires_license  instant_bookable  is_business_travel_ready  \
# 0                 0                 0                         0
# 1                 0                 0                         0
# 3                 0                 0                         0
# 5                 0                 0                         0
# 6                 0                 0                         0
#
#    require_guest_profile_picture  require_guest_phone_verification  \
# 0                              1                                 1
# 1                              0                                 0
# 3                              1                                 1
# 5                              0                                 0
# 6                              1                                 1
#
#    host_verifications_ facebook  host_verifications_ google  \
# 0                             0                           1
# 1                             0                           0
# 3                             0                           0
# 5                             1                           0
# 6                             1                           1
#
#    host_verifications_ government_id  host_verifications_ identity_manual  \
# 0                                  1                                    0
# 1                                  0                                    0
# 3                                  1                                    0
# 5                                  0                                    0
# 6                                  1                                    0
#
#    host_verifications_ jumio  host_verifications_ kba  \
# 0                          1                        0
# 1                          0                        1
# 3                          1                        0
# 5                          0                        0
# 6                          1                        0
#
#    host_verifications_ manual_offline  host_verifications_ manual_online  \
# 0                                   0                                  0
# 1                                   0                                  0
# 3                                   0                                  0
# 5                                   0                                  0
# 6                                   0                                  0
#
#    host_verifications_ offline_government_id  host_verifications_ phone  \
# 0                                          0                          1
# 1                                          0                          1
# 3                                          0                          1
# 5                                          0                          1
# 6                                          0                          1
#
#    host_verifications_ reviews  host_verifications_ selfie  \
# 0                            1                           0
# 1                            1                           0
# 3                            1                           0
# 5                            1                           0
# 6                            1                           0
#
#    host_verifications_ sent_id  host_verifications_ sesame  \
# 0                            0                           0
# 1                            0                           0
# 3                            0                           0
# 5                            0                           0
# 6                            0                           0
#
#    host_verifications_ sesame_offline  host_verifications_ weibo  \
# 0                                   0                          0
# 1                                   0                          0
# 3                                   0                          0
# 5                                   0                          0
# 6                                   0                          0
#
#    host_verifications_ work_email  host_verifications_ zhima_selfie  \
# 0                               0                                 0
# 1                               0                                 0
# 3                               0                                 0
# 5                               0                                 0
# 6                               0                                 0
#
#    host_verifications_email  host_verifications_facebook  \
# 0                         1                            0
# 1                         1                            0
# 3                         1                            0
# 5                         1                            0
# 6                         1                            0
#
#    host_verifications_google  host_verifications_jumio  \
# 0                          0                         0
# 1                          0                         0
# 3                          0                         0
# 5                          0                         0
# 6                          0                         0
#
#    host_verifications_offline_government_id  host_verifications_phone  \
# 0                                         0                         0
# 1                                         0                         0
# 3                                         0                         0
# 5                                         0                         0
# 6                                         0                         0
#
#    host_verifications_reviews  amenities_ toilet  amenities_24-hour check-in  \
# 0                           0                  0                           0
# 1                           0                  0                           1
# 3                           0                  0                           0
# 5                           0                  0                           0
# 6                           0                  0                           0
#
#    amenities_Accessible-height bed  amenities_Accessible-height toilet  \
# 0                                0                                   0
# 1                                0                                   0
# 3                                0                                   0
# 5                                0                                   0
# 6                                0                                   0
#
#    amenities_Air conditioning  amenities_Air purifier  amenities_BBQ grill  \
# 0                           1                       0                    0
# 1                           1                       0                    0
# 3                           0                       0                    0
# 5                           1                       0                    0
# 6                           1                       0                    0
#
#    amenities_Baby bath  amenities_Baby monitor  \
# 0                    0                       0
# 1                    0                       0
# 3                    0                       0
# 5                    0                       0
# 6                    0                       0
#
#    amenities_Babysitter recommendations  amenities_Bathtub  \
# 0                                     0                  0
# 1                                     0                  1
# 3                                     0                  0
# 5                                     0                  0
# 6                                     0                  0
#
#    amenities_Bathtub with bath chair  amenities_Beach essentials  \
# 0                                  0                           0
# 1                                  0                           0
# 3                                  0                           0
# 5                                  0                           0
# 6                                  0                           0
#
#    amenities_Beachfront  amenities_Bed linens  amenities_Breakfast  \
# 0                     0                     0                    0
# 1                     0                     0                    0
# 3                     0                     1                    0
# 5                     0                     1                    0
# 6                     0                     0                    1
#
#    amenities_Building staff  amenities_Buzzer/wireless intercom  \
# 0                         0                                   1
# 1                         0                                   0
# 3                         0                                   1
# 5                         0                                   0
# 6                         0                                   1
#
#    amenities_Cable TV  amenities_Carbon monoxide detector  amenities_Cat(s)  \
# 0                   1                                   1                 0
# 1                   1                                   1                 0
# 3                   1                                   1                 0
# 5                   0                                   0                 0
# 6                   0                                   1                 0
#
#    amenities_Ceiling hoist  amenities_Changing table  \
# 0                        0                         0
# 1                        0                         0
# 3                        0                         0
# 5                        0                         0
# 6                        0                         0
#
#    amenities_Children’s books and toys  amenities_Children’s dinnerware  \
# 0                                    0                                0
# 1                                    1                                0
# 3                                    0                                0
# 5                                    0                                0
# 6                                    0                                0
#
#    amenities_Cleaning before checkout  amenities_Coffee maker  \
# 0                                   0                       0
# 1                                   0                       1
# 3                                   0                       0
# 5                                   0                       0
# 6                                   0                       0
#
#    amenities_Cooking basics  amenities_Crib  amenities_Disabled parking spot  \
# 0                         0               0                                0
# 1                         1               0                                0
# 3                         0               0                                0
# 5                         0               0                                0
# 6                         0               0                                0
#
#    amenities_Dishes and silverware  amenities_Dishwasher  amenities_Dog(s)  \
# 0                                0                     0                 0
# 1                                1                     0                 0
# 3                                0                     0                 0
# 5                                0                     0                 0
# 6                                0                     0                 1
#
#    amenities_Doorman  amenities_Dryer  amenities_EV charger  \
# 0                  0                0                     0
# 1                  0                0                     0
# 3                  0                0                     0
# 5                  0                0                     0
# 6                  1                0                     0
#
#    amenities_Electric profiling bed  amenities_Elevator  amenities_Essentials  \
# 0                                 0                   0                     0
# 1                                 0                   0                     1
# 3                                 0                   0                     1
# 5                                 0                   0                     1
# 6                                 0                   1                     1
#
#    amenities_Ethernet connection  amenities_Extra pillows and blankets  \
# 0                              0                                     0
# 1                              0                                     0
# 3                              0                                     1
# 5                              0                                     1
# 6                              0                                     0
#
#    amenities_Extra space around bed  amenities_Family/kid friendly  \
# 0                                 0                              0
# 1                                 0                              1
# 3                                 0                              0
# 5                                 0                              1
# 6                                 0                              0
#
#    amenities_Fire extinguisher  amenities_Fireplace guards  \
# 0                            0                           0
# 1                            1                           0
# 3                            1                           0
# 5                            0                           0
# 6                            1                           0
#
#    amenities_Firm mattress  amenities_First aid kit  \
# 0                        0                        0
# 1                        0                        0
# 3                        0                        0
# 5                        0                        0
# 6                        0                        0
#
#    amenities_Fixed grab bars for shower  amenities_Fixed grab bars for toilet  \
# 0                                     0                                     0
# 1                                     0                                     0
# 3                                     0                                     0
# 5                                     0                                     0
# 6                                     0                                     0
#
#    amenities_Flat path to guest entrance  amenities_Free parking on premises  \
# 0                                      0                                   0
# 1                                      0                                   0
# 3                                      0                                   0
# 5                                      0                                   0
# 6                                      0                                   0
#
#    amenities_Free street parking  amenities_Full kitchen  \
# 0                              0                       0
# 1                              1                       0
# 3                              0                       0
# 5                              1                       0
# 6                              1                       0
#
#    amenities_Game console  amenities_Garden or backyard  \
# 0                       0                             0
# 1                       0                             0
# 3                       0                             0
# 5                       0                             0
# 6                       0                             0
#
#    amenities_Ground floor access  amenities_Gym  amenities_Hair dryer  \
# 0                              0              0                     0
# 1                              0              0                     1
# 3                              0              0                     1
# 5                              0              0                     1
# 6                              0              0                     1
#
#    amenities_Handheld shower head  amenities_Hangers  amenities_Heating  \
# 0                               0                  0                  1
# 1                               0                  1                  1
# 3                               0                  1                  1
# 5                               0                  1                  1
# 6                               0                  0                  1
#
#    amenities_High chair  amenities_Host greets you  amenities_Hot tub  \
# 0                     0                          0                  0
# 1                     1                          0                  0
# 3                     0                          1                  0
# 5                     0                          0                  0
# 6                     0                          1                  0
#
#    amenities_Hot water  amenities_Hot water kettle  \
# 0                    0                           0
# 1                    1                           0
# 3                    1                           0
# 5                    0                           0
# 6                    1                           0
#
#    amenities_Indoor fireplace  amenities_Internet  amenities_Iron  \
# 0                           0                   1               0
# 1                           0                   1               1
# 3                           0                   1               1
# 5                           0                   0               1
# 6                           0                   1               0
#
#    amenities_Keypad  amenities_Kitchen  amenities_Kitchenette  \
# 0                 0                  1                      0
# 1                 0                  1                      0
# 3                 0                  1                      0
# 5                 0                  0                      0
# 6                 0                  0                      0
#
#    amenities_Lake access  amenities_Laptop friendly workspace  \
# 0                      0                                    0
# 1                      0                                    1
# 3                      0                                    1
# 5                      0                                    0
# 6                      0                                    1
#
#    amenities_Lock on bedroom door  amenities_Lockbox  \
# 0                               0                  0
# 1                               1                  1
# 3                               0                  0
# 5                               1                  0
# 6                               0                  0
#
#    amenities_Long term stays allowed  amenities_Luggage dropoff allowed  \
# 0                                  0                                  0
# 1                                  1                                  1
# 3                                  0                                  0
# 5                                  0                                  1
# 6                                  0                                  0
#
#    amenities_Microwave  amenities_Mobile hoist  \
# 0                    0                       0
# 1                    1                       0
# 3                    0                       0
# 5                    1                       0
# 6                    0                       0
#
#    amenities_No stairs or steps to enter  amenities_Other  \
# 0                                      0                0
# 1                                      0                0
# 3                                      0                0
# 5                                      0                0
# 6                                      0                0
#
#    amenities_Other pet(s)  amenities_Outlet covers  amenities_Oven  \
# 0                       0                        0               0
# 1                       0                        0               1
# 3                       0                        0               0
# 5                       0                        0               0
# 6                       0                        0               0
#
#    amenities_Pack ’n Play/travel crib  amenities_Paid parking off premises  \
# 0                                   0                                    0
# 1                                   1                                    0
# 3                                   0                                    0
# 5                                   0                                    1
# 6                                   0                                    1
#
#    amenities_Paid parking on premises  amenities_Patio or balcony  \
# 0                                   0                           0
# 1                                   0                           0
# 3                                   0                           0
# 5                                   0                           0
# 6                                   0                           0
#
#    amenities_Pets allowed  amenities_Pets live on this property  \
# 0                       0                                     0
# 1                       1                                     0
# 3                       0                                     0
# 5                       0                                     0
# 6                       0                                     1
#
#    amenities_Pocket wifi  amenities_Pool  amenities_Pool with pool hoist  \
# 0                      0               0                               0
# 1                      0               0                               0
# 3                      0               0                               0
# 5                      0               0                               0
# 6                      0               0                               0
#
#    amenities_Private bathroom  amenities_Private entrance  \
# 0                           0                           0
# 1                           0                           0
# 3                           0                           0
# 5                           0                           0
# 6                           0                           0
#
#    amenities_Private living room  amenities_Refrigerator  \
# 0                              0                       0
# 1                              0                       1
# 3                              0                       0
# 5                              0                       1
# 6                              0                       0
#
#    amenities_Roll-in shower  amenities_Room-darkening shades  \
# 0                         0                                0
# 1                         0                                0
# 3                         0                                0
# 5                         0                                0
# 6                         0                                0
#
#    amenities_Safety card  amenities_Self check-in  amenities_Shampoo  \
# 0                      0                        0                  0
# 1                      0                        1                  1
# 3                      0                        0                  1
# 5                      0                        0                  1
# 6                      0                        0                  1
#
#    amenities_Shower chair  amenities_Single level home  \
# 0                       0                            0
# 1                       0                            0
# 3                       0                            0
# 5                       0                            0
# 6                       0                            0
#
#    amenities_Ski-in/Ski-out  amenities_Smart lock  amenities_Smoke detector  \
# 0                         0                     0                         1
# 1                         0                     0                         1
# 3                         0                     0                         1
# 5                         0                     0                         1
# 6                         0                     0                         1
#
#    amenities_Smoking allowed  amenities_Stair gates  amenities_Stove  \
# 0                          0                      0                0
# 1                          0                      1                1
# 3                          0                      0                0
# 5                          0                      0                0
# 6                          0                      0                0
#
#    amenities_Suitable for events  amenities_TV  amenities_Table corner guards  \
# 0                              0             0                              0
# 1                              0             1                              0
# 3                              0             1                              0
# 5                              0             1                              0
# 6                              0             0                              0
#
#    amenities_Washer  amenities_Washer / Dryer  amenities_Waterfront  \
# 0                 0                         0                     0
# 1                 0                         0                     0
# 3                 0                         0                     0
# 5                 0                         0                     0
# 6                 0                         0                     0
#
#    amenities_Well-lit path to entrance  amenities_Wheelchair accessible  \
# 0                                    0                                0
# 1                                    0                                0
# 3                                    0                                0
# 5                                    0                                0
# 6                                    0                                0
#
#    amenities_Wide clearance to shower  \
# 0                                   0
# 1                                   0
# 3                                   0
# 5                                   0
# 6                                   0
#
#    amenities_Wide doorway to guest bathroom  amenities_Wide entrance  \
# 0                                         0                        0
# 1                                         0                        0
# 3                                         0                        0
# 5                                         0                        0
# 6                                         0                        0
#
#    amenities_Wide entrance for guests  amenities_Wide entryway  \
# 0                                   0                        0
# 1                                   0                        0
# 3                                   0                        0
# 5                                   0                        0
# 6                                   0                        0
#
#    amenities_Wide hallways  amenities_Wifi  amenities_Window guards  \
# 0                        0               1                        0
# 1                        0               1                        0
# 3                        0               1                        0
# 5                        0               1                        0
# 6                        0               1                        0
#
#    amenities_translation missing: en.hosting_amenity_49  \
# 0                                                  1
# 1                                                  0
# 3                                                  1
# 5                                                  0
# 6                                                  1
#
#    amenities_translation missing: en.hosting_amenity_50
# 0                                                  1
# 1                                                  0
# 3                                                  1
# 5                                                  1
# 6                                                  1

# %%
for col in list(data.columns):
    null_ratio = pd.isnull(data[col]).sum()/len(data)*100
    if null_ratio > 0:
        print("%0.2f %% observations missing for %s." % (float(null_ratio),col))
# Out:
# 33.72 % observations missing for host_response_rate.
# 21.78 % observations missing for review_scores_rating.
# 21.86 % observations missing for review_scores_accuracy.
# 21.83 % observations missing for review_scores_cleanliness.
# 21.90 % observations missing for review_scores_checkin.
# 21.85 % observations missing for review_scores_communication.
# 21.90 % observations missing for review_scores_location.
# 21.90 % observations missing for review_scores_value.
# 19.91 % observations missing for reviews_per_month.
# 21.08 % observations missing for cleaning_fee.
# 34.90 % observations missing for security_deposit.

# %%
list(data.columns)
# Out:
# ['host_response_rate',
#  'host_listings_count',
#  'host_total_listings_count',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'zipcode',
#  'smart_location',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'guests_included',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'cancellation_policy',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month',
#  'extra_people',
#  'cleaning_fee',
#  'security_deposit',
#  'price',
#  'host_is_superhost',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'has_availability',
#  'requires_license',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'host_verifications_ facebook',
#  'host_verifications_ google',
#  'host_verifications_ government_id',
#  'host_verifications_ identity_manual',
#  'host_verifications_ jumio',
#  'host_verifications_ kba',
#  'host_verifications_ manual_offline',
#  'host_verifications_ manual_online',
#  'host_verifications_ offline_government_id',
#  'host_verifications_ phone',
#  'host_verifications_ reviews',
#  'host_verifications_ selfie',
#  'host_verifications_ sent_id',
#  'host_verifications_ sesame',
#  'host_verifications_ sesame_offline',
#  'host_verifications_ weibo',
#  'host_verifications_ work_email',
#  'host_verifications_ zhima_selfie',
#  'host_verifications_email',
#  'host_verifications_facebook',
#  'host_verifications_google',
#  'host_verifications_jumio',
#  'host_verifications_offline_government_id',
#  'host_verifications_phone',
#  'host_verifications_reviews',
#  'amenities_ toilet',
#  'amenities_24-hour check-in',
#  'amenities_Accessible-height bed',
#  'amenities_Accessible-height toilet',
#  'amenities_Air conditioning',
#  'amenities_Air purifier',
#  'amenities_BBQ grill',
#  'amenities_Baby bath',
#  'amenities_Baby monitor',
#  'amenities_Babysitter recommendations',
#  'amenities_Bathtub',
#  'amenities_Bathtub with bath chair',
#  'amenities_Beach essentials',
#  'amenities_Beachfront',
#  'amenities_Bed linens',
#  'amenities_Breakfast',
#  'amenities_Building staff',
#  'amenities_Buzzer/wireless intercom',
#  'amenities_Cable TV',
#  'amenities_Carbon monoxide detector',
#  'amenities_Cat(s)',
#  'amenities_Ceiling hoist',
#  'amenities_Changing table',
#  'amenities_Children’s books and toys',
#  'amenities_Children’s dinnerware',
#  'amenities_Cleaning before checkout',
#  'amenities_Coffee maker',
#  'amenities_Cooking basics',
#  'amenities_Crib',
#  'amenities_Disabled parking spot',
#  'amenities_Dishes and silverware',
#  'amenities_Dishwasher',
#  'amenities_Dog(s)',
#  'amenities_Doorman',
#  'amenities_Dryer',
#  'amenities_EV charger',
#  'amenities_Electric profiling bed',
#  'amenities_Elevator',
#  'amenities_Essentials',
#  'amenities_Ethernet connection',
#  'amenities_Extra pillows and blankets',
#  'amenities_Extra space around bed',
#  'amenities_Family/kid friendly',
#  'amenities_Fire extinguisher',
#  'amenities_Fireplace guards',
#  'amenities_Firm mattress',
#  'amenities_First aid kit',
#  'amenities_Fixed grab bars for shower',
#  'amenities_Fixed grab bars for toilet',
#  'amenities_Flat path to guest entrance',
#  'amenities_Free parking on premises',
#  'amenities_Free street parking',
#  'amenities_Full kitchen',
#  'amenities_Game console',
#  'amenities_Garden or backyard',
#  'amenities_Ground floor access',
#  'amenities_Gym',
#  'amenities_Hair dryer',
#  'amenities_Handheld shower head',
#  'amenities_Hangers',
#  'amenities_Heating',
#  'amenities_High chair',
#  'amenities_Host greets you',
#  'amenities_Hot tub',
#  'amenities_Hot water',
#  'amenities_Hot water kettle',
#  'amenities_Indoor fireplace',
#  'amenities_Internet',
#  'amenities_Iron',
#  'amenities_Keypad',
#  'amenities_Kitchen',
#  'amenities_Kitchenette',
#  'amenities_Lake access',
#  'amenities_Laptop friendly workspace',
#  'amenities_Lock on bedroom door',
#  'amenities_Lockbox',
#  'amenities_Long term stays allowed',
#  'amenities_Luggage dropoff allowed',
#  'amenities_Microwave',
#  'amenities_Mobile hoist',
#  'amenities_No stairs or steps to enter',
#  'amenities_Other',
#  'amenities_Other pet(s)',
#  'amenities_Outlet covers',
#  'amenities_Oven',
#  'amenities_Pack ’n Play/travel crib',
#  'amenities_Paid parking off premises',
#  'amenities_Paid parking on premises',
#  'amenities_Patio or balcony',
#  'amenities_Pets allowed',
#  'amenities_Pets live on this property',
#  'amenities_Pocket wifi',
#  'amenities_Pool',
#  'amenities_Pool with pool hoist',
#  'amenities_Private bathroom',
#  'amenities_Private entrance',
#  'amenities_Private living room',
#  'amenities_Refrigerator',
#  'amenities_Roll-in shower',
#  'amenities_Room-darkening shades',
#  'amenities_Safety card',
#  'amenities_Self check-in',
#  'amenities_Shampoo',
#  'amenities_Shower chair',
#  'amenities_Single level home',
#  'amenities_Ski-in/Ski-out',
#  'amenities_Smart lock',
#  'amenities_Smoke detector',
#  'amenities_Smoking allowed',
#  'amenities_Stair gates',
#  'amenities_Stove',
#  'amenities_Suitable for events',
#  'amenities_TV',
#  'amenities_Table corner guards',
#  'amenities_Washer',
#  'amenities_Washer / Dryer',
#  'amenities_Waterfront',
#  'amenities_Well-lit path to entrance',
#  'amenities_Wheelchair accessible',
#  'amenities_Wide clearance to shower',
#  'amenities_Wide doorway to guest bathroom',
#  'amenities_Wide entrance',
#  'amenities_Wide entrance for guests',
#  'amenities_Wide entryway',
#  'amenities_Wide hallways',
#  'amenities_Wifi',
#  'amenities_Window guards',
#  'amenities_translation missing: en.hosting_amenity_49',
#  'amenities_translation missing: en.hosting_amenity_50']

# %% [markdown]
# ### 2.7 One Hot Encoding
# We will now look at the unique values in each string column.
# If there are too many distinct values (i.e, 10) we will delete the column to avoid explosion in columns.
# We will make an exception for `property_type` and `neighbourhood` as we believe these features have powerful predicting power.

# %%
strColumn = data.select_dtypes(include='object')
for name in strColumn:
    print(name,data[name].nunique())
# Out:
# neighbourhood_cleansed 224
# neighbourhood_group_cleansed 5
# city 309
# smart_location 317
# property_type 36
# room_type 4
# bed_type 5
# calendar_updated 91
# cancellation_policy 6

# %%
strColumn = data.select_dtypes(include='object')

columnDrop = []
for name in strColumn:

    if data[name].nunique() > 40:
        columnDrop.append(name)
print("We will drop these columns to avoid column explosion",columnDrop)
data = data.drop(columns=columnDrop,axis = 1)
print(data.shape)
# Out:
# We will drop these columns to avoid column explosion ['neighbourhood_cleansed', 'city', 'smart_location', 'calendar_updated']
# (47720, 209)

# %%
strColumn = data.select_dtypes(include='object')
for name in strColumn:
    print(name,data[name].nunique())
# Out:
# neighbourhood_group_cleansed 5
# property_type 36
# room_type 4
# bed_type 5
# cancellation_policy 6

# %%
strColumn = data.select_dtypes(include='object')
dummy_list = []

for name in strColumn.columns:
    if data[name].nunique() == 1:
        print("1", name)
    else:
        dummies = pd.get_dummies(data[name])
        dummies = dummies.add_prefix(name + '_')
        data = data.drop(columns=[name])
        print(name)
        data = pd.concat([data,dummies],axis = 1)
# Out:
# neighbourhood_group_cleansed
# property_type
# room_type
# bed_type
# cancellation_policy

# %%
data.to_csv(os.getcwd()+'/data/airbnb_no_impute_20191202.csv.gz', index=False, compression='gzip')

# %%
list(data.columns)
# Out:
# ['host_response_rate',
#  'host_listings_count',
#  'host_total_listings_count',
#  'zipcode',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'guests_included',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month',
#  'extra_people',
#  'cleaning_fee',
#  'security_deposit',
#  'price',
#  'host_is_superhost',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'has_availability',
#  'requires_license',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'host_verifications_ facebook',
#  'host_verifications_ google',
#  'host_verifications_ government_id',
#  'host_verifications_ identity_manual',
#  'host_verifications_ jumio',
#  'host_verifications_ kba',
#  'host_verifications_ manual_offline',
#  'host_verifications_ manual_online',
#  'host_verifications_ offline_government_id',
#  'host_verifications_ phone',
#  'host_verifications_ reviews',
#  'host_verifications_ selfie',
#  'host_verifications_ sent_id',
#  'host_verifications_ sesame',
#  'host_verifications_ sesame_offline',
#  'host_verifications_ weibo',
#  'host_verifications_ work_email',
#  'host_verifications_ zhima_selfie',
#  'host_verifications_email',
#  'host_verifications_facebook',
#  'host_verifications_google',
#  'host_verifications_jumio',
#  'host_verifications_offline_government_id',
#  'host_verifications_phone',
#  'host_verifications_reviews',
#  'amenities_ toilet',
#  'amenities_24-hour check-in',
#  'amenities_Accessible-height bed',
#  'amenities_Accessible-height toilet',
#  'amenities_Air conditioning',
#  'amenities_Air purifier',
#  'amenities_BBQ grill',
#  'amenities_Baby bath',
#  'amenities_Baby monitor',
#  'amenities_Babysitter recommendations',
#  'amenities_Bathtub',
#  'amenities_Bathtub with bath chair',
#  'amenities_Beach essentials',
#  'amenities_Beachfront',
#  'amenities_Bed linens',
#  'amenities_Breakfast',
#  'amenities_Building staff',
#  'amenities_Buzzer/wireless intercom',
#  'amenities_Cable TV',
#  'amenities_Carbon monoxide detector',
#  'amenities_Cat(s)',
#  'amenities_Ceiling hoist',
#  'amenities_Changing table',
#  'amenities_Children’s books and toys',
#  'amenities_Children’s dinnerware',
#  'amenities_Cleaning before checkout',
#  'amenities_Coffee maker',
#  'amenities_Cooking basics',
#  'amenities_Crib',
#  'amenities_Disabled parking spot',
#  'amenities_Dishes and silverware',
#  'amenities_Dishwasher',
#  'amenities_Dog(s)',
#  'amenities_Doorman',
#  'amenities_Dryer',
#  'amenities_EV charger',
#  'amenities_Electric profiling bed',
#  'amenities_Elevator',
#  'amenities_Essentials',
#  'amenities_Ethernet connection',
#  'amenities_Extra pillows and blankets',
#  'amenities_Extra space around bed',
#  'amenities_Family/kid friendly',
#  'amenities_Fire extinguisher',
#  'amenities_Fireplace guards',
#  'amenities_Firm mattress',
#  'amenities_First aid kit',
#  'amenities_Fixed grab bars for shower',
#  'amenities_Fixed grab bars for toilet',
#  'amenities_Flat path to guest entrance',
#  'amenities_Free parking on premises',
#  'amenities_Free street parking',
#  'amenities_Full kitchen',
#  'amenities_Game console',
#  'amenities_Garden or backyard',
#  'amenities_Ground floor access',
#  'amenities_Gym',
#  'amenities_Hair dryer',
#  'amenities_Handheld shower head',
#  'amenities_Hangers',
#  'amenities_Heating',
#  'amenities_High chair',
#  'amenities_Host greets you',
#  'amenities_Hot tub',
#  'amenities_Hot water',
#  'amenities_Hot water kettle',
#  'amenities_Indoor fireplace',
#  'amenities_Internet',
#  'amenities_Iron',
#  'amenities_Keypad',
#  'amenities_Kitchen',
#  'amenities_Kitchenette',
#  'amenities_Lake access',
#  'amenities_Laptop friendly workspace',
#  'amenities_Lock on bedroom door',
#  'amenities_Lockbox',
#  'amenities_Long term stays allowed',
#  'amenities_Luggage dropoff allowed',
#  'amenities_Microwave',
#  'amenities_Mobile hoist',
#  'amenities_No stairs or steps to enter',
#  'amenities_Other',
#  'amenities_Other pet(s)',
#  'amenities_Outlet covers',
#  'amenities_Oven',
#  'amenities_Pack ’n Play/travel crib',
#  'amenities_Paid parking off premises',
#  'amenities_Paid parking on premises',
#  'amenities_Patio or balcony',
#  'amenities_Pets allowed',
#  'amenities_Pets live on this property',
#  'amenities_Pocket wifi',
#  'amenities_Pool',
#  'amenities_Pool with pool hoist',
#  'amenities_Private bathroom',
#  'amenities_Private entrance',
#  'amenities_Private living room',
#  'amenities_Refrigerator',
#  'amenities_Roll-in shower',
#  'amenities_Room-darkening shades',
#  'amenities_Safety card',
#  'amenities_Self check-in',
#  'amenities_Shampoo',
#  'amenities_Shower chair',
#  'amenities_Single level home',
#  'amenities_Ski-in/Ski-out',
#  'amenities_Smart lock',
#  'amenities_Smoke detector',
#  'amenities_Smoking allowed',
#  'amenities_Stair gates',
#  'amenities_Stove',
#  'amenities_Suitable for events',
#  'amenities_TV',
#  'amenities_Table corner guards',
#  'amenities_Washer',
#  'amenities_Washer / Dryer',
#  'amenities_Waterfront',
#  'amenities_Well-lit path to entrance',
#  'amenities_Wheelchair accessible',
#  'amenities_Wide clearance to shower',
#  'amenities_Wide doorway to guest bathroom',
#  'amenities_Wide entrance',
#  'amenities_Wide entrance for guests',
#  'amenities_Wide entryway',
#  'amenities_Wide hallways',
#  'amenities_Wifi',
#  'amenities_Window guards',
#  'amenities_translation missing: en.hosting_amenity_49',
#  'amenities_translation missing: en.hosting_amenity_50',
#  'neighbourhood_cleansed_Allerton',
#  'neighbourhood_cleansed_Arden Heights',
#  'neighbourhood_cleansed_Arrochar',
#  'neighbourhood_cleansed_Arverne',
#  'neighbourhood_cleansed_Astoria',
#  'neighbourhood_cleansed_Bath Beach',
#  'neighbourhood_cleansed_Battery Park City',
#  'neighbourhood_cleansed_Bay Ridge',
#  'neighbourhood_cleansed_Bay Terrace',
#  'neighbourhood_cleansed_Bay Terrace, Staten Island',
#  'neighbourhood_cleansed_Baychester',
#  'neighbourhood_cleansed_Bayside',
#  'neighbourhood_cleansed_Bayswater',
#  'neighbourhood_cleansed_Bedford-Stuyvesant',
#  'neighbourhood_cleansed_Belle Harbor',
#  'neighbourhood_cleansed_Bellerose',
#  'neighbourhood_cleansed_Belmont',
#  'neighbourhood_cleansed_Bensonhurst',
#  'neighbourhood_cleansed_Bergen Beach',
#  'neighbourhood_cleansed_Boerum Hill',
#  'neighbourhood_cleansed_Borough Park',
#  'neighbourhood_cleansed_Breezy Point',
#  'neighbourhood_cleansed_Briarwood',
#  'neighbourhood_cleansed_Brighton Beach',
#  'neighbourhood_cleansed_Bronxdale',
#  'neighbourhood_cleansed_Brooklyn Heights',
#  'neighbourhood_cleansed_Brownsville',
#  "neighbourhood_cleansed_Bull's Head",
#  'neighbourhood_cleansed_Bushwick',
#  'neighbourhood_cleansed_Cambria Heights',
#  'neighbourhood_cleansed_Canarsie',
#  'neighbourhood_cleansed_Carroll Gardens',
#  'neighbourhood_cleansed_Castle Hill',
#  'neighbourhood_cleansed_Castleton Corners',
#  'neighbourhood_cleansed_Charleston',
#  'neighbourhood_cleansed_Chelsea',
#  'neighbourhood_cleansed_Chinatown',
#  'neighbourhood_cleansed_City Island',
#  'neighbourhood_cleansed_Civic Center',
#  'neighbourhood_cleansed_Claremont Village',
#  'neighbourhood_cleansed_Clason Point',
#  'neighbourhood_cleansed_Clifton',
#  'neighbourhood_cleansed_Clinton Hill',
#  'neighbourhood_cleansed_Co-op City',
#  'neighbourhood_cleansed_Cobble Hill',
#  'neighbourhood_cleansed_College Point',
#  'neighbourhood_cleansed_Columbia St',
#  'neighbourhood_cleansed_Concord',
#  'neighbourhood_cleansed_Concourse',
#  'neighbourhood_cleansed_Concourse Village',
#  'neighbourhood_cleansed_Coney Island',
#  'neighbourhood_cleansed_Corona',
#  'neighbourhood_cleansed_Country Club',
#  'neighbourhood_cleansed_Crown Heights',
#  'neighbourhood_cleansed_Cypress Hills',
#  'neighbourhood_cleansed_DUMBO',
#  'neighbourhood_cleansed_Ditmars Steinway',
#  'neighbourhood_cleansed_Dongan Hills',
#  'neighbourhood_cleansed_Douglaston',
#  'neighbourhood_cleansed_Downtown Brooklyn',
#  'neighbourhood_cleansed_Dyker Heights',
#  'neighbourhood_cleansed_East Elmhurst',
#  'neighbourhood_cleansed_East Flatbush',
#  'neighbourhood_cleansed_East Harlem',
#  'neighbourhood_cleansed_East Morrisania',
#  'neighbourhood_cleansed_East New York',
#  'neighbourhood_cleansed_East Village',
#  'neighbourhood_cleansed_Eastchester',
#  'neighbourhood_cleansed_Edenwald',
#  'neighbourhood_cleansed_Edgemere',
#  'neighbourhood_cleansed_Elmhurst',
#  'neighbourhood_cleansed_Eltingville',
#  'neighbourhood_cleansed_Emerson Hill',
#  'neighbourhood_cleansed_Far Rockaway',
#  'neighbourhood_cleansed_Fieldston',
#  'neighbourhood_cleansed_Financial District',
#  'neighbourhood_cleansed_Flatbush',
#  'neighbourhood_cleansed_Flatiron District',
#  'neighbourhood_cleansed_Flatlands',
#  'neighbourhood_cleansed_Flushing',
#  'neighbourhood_cleansed_Fordham',
#  'neighbourhood_cleansed_Forest Hills',
#  'neighbourhood_cleansed_Fort Greene',
#  'neighbourhood_cleansed_Fort Hamilton',
#  'neighbourhood_cleansed_Fort Wadsworth',
#  'neighbourhood_cleansed_Fresh Meadows',
#  'neighbourhood_cleansed_Gerritsen Beach',
#  'neighbourhood_cleansed_Glendale',
#  'neighbourhood_cleansed_Gowanus',
#  'neighbourhood_cleansed_Gramercy',
#  'neighbourhood_cleansed_Graniteville',
#  'neighbourhood_cleansed_Grant City',
#  'neighbourhood_cleansed_Gravesend',
#  'neighbourhood_cleansed_Great Kills',
#  'neighbourhood_cleansed_Greenpoint',
#  'neighbourhood_cleansed_Greenwich Village',
#  'neighbourhood_cleansed_Grymes Hill',
#  'neighbourhood_cleansed_Harlem',
#  "neighbourhood_cleansed_Hell's Kitchen",
#  'neighbourhood_cleansed_Highbridge',
#  'neighbourhood_cleansed_Hollis',
#  'neighbourhood_cleansed_Holliswood',
#  'neighbourhood_cleansed_Howard Beach',
#  'neighbourhood_cleansed_Howland Hook',
#  'neighbourhood_cleansed_Huguenot',
#  'neighbourhood_cleansed_Hunts Point',
#  'neighbourhood_cleansed_Inwood',
#  'neighbourhood_cleansed_Jackson Heights',
#  'neighbourhood_cleansed_Jamaica',
#  'neighbourhood_cleansed_Jamaica Estates',
#  'neighbourhood_cleansed_Jamaica Hills',
#  'neighbourhood_cleansed_Kensington',
#  'neighbourhood_cleansed_Kew Gardens',
#  'neighbourhood_cleansed_Kew Gardens Hills',
#  'neighbourhood_cleansed_Kingsbridge',
#  'neighbourhood_cleansed_Kips Bay',
#  'neighbourhood_cleansed_Laurelton',
#  'neighbourhood_cleansed_Lighthouse Hill',
#  'neighbourhood_cleansed_Little Italy',
#  'neighbourhood_cleansed_Little Neck',
#  'neighbourhood_cleansed_Long Island City',
#  'neighbourhood_cleansed_Longwood',
#  'neighbourhood_cleansed_Lower East Side',
#  'neighbourhood_cleansed_Manhattan Beach',
#  'neighbourhood_cleansed_Marble Hill',
#  'neighbourhood_cleansed_Mariners Harbor',
#  'neighbourhood_cleansed_Maspeth',
#  'neighbourhood_cleansed_Melrose',
#  'neighbourhood_cleansed_Middle Village',
#  'neighbourhood_cleansed_Midland Beach',
#  'neighbourhood_cleansed_Midtown',
#  'neighbourhood_cleansed_Midwood',
#  'neighbourhood_cleansed_Mill Basin',
#  'neighbourhood_cleansed_Morningside Heights',
#  'neighbourhood_cleansed_Morris Heights',
#  'neighbourhood_cleansed_Morris Park',
#  'neighbourhood_cleansed_Morrisania',
#  'neighbourhood_cleansed_Mott Haven',
#  'neighbourhood_cleansed_Mount Eden',
#  'neighbourhood_cleansed_Mount Hope',
#  'neighbourhood_cleansed_Murray Hill',
#  'neighbourhood_cleansed_Navy Yard',
#  'neighbourhood_cleansed_Neponsit',
#  'neighbourhood_cleansed_New Brighton',
#  'neighbourhood_cleansed_New Dorp',
#  'neighbourhood_cleansed_New Dorp Beach',
#  'neighbourhood_cleansed_New Springville',
#  'neighbourhood_cleansed_NoHo',
#  'neighbourhood_cleansed_Nolita',
#  'neighbourhood_cleansed_North Riverdale',
#  'neighbourhood_cleansed_Norwood',
#  'neighbourhood_cleansed_Oakwood',
#  'neighbourhood_cleansed_Olinville',
#  'neighbourhood_cleansed_Ozone Park',
#  'neighbourhood_cleansed_Park Slope',
#  'neighbourhood_cleansed_Parkchester',
#  'neighbourhood_cleansed_Pelham Bay',
#  'neighbourhood_cleansed_Pelham Gardens',
#  'neighbourhood_cleansed_Port Morris',
#  'neighbourhood_cleansed_Port Richmond',
#  "neighbourhood_cleansed_Prince's Bay",
#  'neighbourhood_cleansed_Prospect Heights',
#  'neighbourhood_cleansed_Prospect-Lefferts Gardens',
#  'neighbourhood_cleansed_Queens Village',
#  'neighbourhood_cleansed_Randall Manor',
#  'neighbourhood_cleansed_Red Hook',
#  'neighbourhood_cleansed_Rego Park',
#  'neighbourhood_cleansed_Richmond Hill',
#  'neighbourhood_cleansed_Richmondtown',
#  'neighbourhood_cleansed_Ridgewood',
#  'neighbourhood_cleansed_Riverdale',
#  'neighbourhood_cleansed_Rockaway Beach',
#  'neighbourhood_cleansed_Roosevelt Island',
#  'neighbourhood_cleansed_Rosebank',
#  'neighbourhood_cleansed_Rosedale',
#  'neighbourhood_cleansed_Rossville',
#  'neighbourhood_cleansed_Schuylerville',
#  'neighbourhood_cleansed_Sea Gate',
#  'neighbourhood_cleansed_Sheepshead Bay',
#  'neighbourhood_cleansed_Shore Acres',
#  'neighbourhood_cleansed_Silver Lake',
#  'neighbourhood_cleansed_SoHo',
#  'neighbourhood_cleansed_Soundview',
#  'neighbourhood_cleansed_South Beach',
#  'neighbourhood_cleansed_South Ozone Park',
#  'neighbourhood_cleansed_South Slope',
#  'neighbourhood_cleansed_Springfield Gardens',
#  'neighbourhood_cleansed_Spuyten Duyvil',
#  'neighbourhood_cleansed_St. Albans',
#  'neighbourhood_cleansed_St. George',
#  'neighbourhood_cleansed_Stapleton',
#  'neighbourhood_cleansed_Stuyvesant Town',
#  'neighbourhood_cleansed_Sunnyside',
#  'neighbourhood_cleansed_Sunset Park',
#  'neighbourhood_cleansed_Theater District',
#  'neighbourhood_cleansed_Throgs Neck',
#  'neighbourhood_cleansed_Todt Hill',
#  'neighbourhood_cleansed_Tompkinsville',
#  'neighbourhood_cleansed_Tottenville',
#  'neighbourhood_cleansed_Tremont',
#  'neighbourhood_cleansed_Tribeca',
#  'neighbourhood_cleansed_Two Bridges',
#  'neighbourhood_cleansed_Unionport',
#  'neighbourhood_cleansed_University Heights',
#  'neighbourhood_cleansed_Upper East Side',
#  'neighbourhood_cleansed_Upper West Side',
#  'neighbourhood_cleansed_Van Nest',
#  'neighbourhood_cleansed_Vinegar Hill',
#  'neighbourhood_cleansed_Wakefield',
#  'neighbourhood_cleansed_Washington Heights',
#  'neighbourhood_cleansed_West Brighton',
#  'neighbourhood_cleansed_West Farms',
#  'neighbourhood_cleansed_West Village',
#  'neighbourhood_cleansed_Westchester Square',
#  'neighbourhood_cleansed_Westerleigh',
#  'neighbourhood_cleansed_Whitestone',
#  'neighbourhood_cleansed_Williamsbridge',
#  'neighbourhood_cleansed_Williamsburg',
#  'neighbourhood_cleansed_Willowbrook',
#  'neighbourhood_cleansed_Windsor Terrace',
#  'neighbourhood_cleansed_Woodhaven',
#  'neighbourhood_cleansed_Woodlawn',
#  'neighbourhood_cleansed_Woodrow',
#  'neighbourhood_cleansed_Woodside',
#  'neighbourhood_group_cleansed_Bronx',
#  'neighbourhood_group_cleansed_Brooklyn',
#  'neighbourhood_group_cleansed_Manhattan',
#  'neighbourhood_group_cleansed_Queens',
#  'neighbourhood_group_cleansed_Staten Island',
#  'property_type_Aparthotel',
#  'property_type_Apartment',
#  'property_type_Barn',
#  'property_type_Bed and breakfast',
#  'property_type_Boat',
#  'property_type_Boutique hotel',
#  'property_type_Bungalow',
#  'property_type_Bus',
#  'property_type_Cabin',
#  'property_type_Camper/RV',
#  'property_type_Casa particular (Cuba)',
#  'property_type_Castle',
#  'property_type_Cave',
#  'property_type_Condominium',
#  'property_type_Cottage',
#  'property_type_Dome house',
#  'property_type_Earth house',
#  'property_type_Farm stay',
#  'property_type_Guest suite',
#  'property_type_Guesthouse',
#  'property_type_Hostel',
#  'property_type_Hotel',
#  'property_type_House',
#  'property_type_Houseboat',
#  'property_type_Island',
#  'property_type_Loft',
#  'property_type_Nature lodge',
#  'property_type_Other',
#  'property_type_Resort',
#  'property_type_Serviced apartment',
#  'property_type_Tent',
#  'property_type_Timeshare',
#  'property_type_Tiny house',
#  'property_type_Townhouse',
#  'property_type_Villa',
#  'property_type_Yurt',
#  'room_type_Entire home/apt',
#  'room_type_Hotel room',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'bed_type_Airbed',
#  'bed_type_Couch',
#  'bed_type_Futon',
#  'bed_type_Pull-out Sofa',
#  'bed_type_Real Bed',
#  'cancellation_policy_flexible',
#  'cancellation_policy_moderate',
#  'cancellation_policy_strict',
#  'cancellation_policy_strict_14_with_grace_period',
#  'cancellation_policy_super_strict_30',
#  'cancellation_policy_super_strict_60']

# %% [markdown]
# ### Done!
